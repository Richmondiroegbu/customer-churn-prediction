# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from feature_engine.outliers import Winsorizer
from sklearn.cluster import DBSCAN
from scipy.spatial.distance import cdist
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import PowerTransformer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
df = pd.read_excel("../churn data/Online Retail.xlsx")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541909.000000                         541909  541909.000000
# mean        9.552250  2011-07-04 13:34:57.156386048       4.611114
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:34:00       1.250000
# 50%         3.000000            2011-07-19 17:17:00       2.080000
# 75%        10.000000            2011-10-19 11:27:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.081158                            NaN      96.759853
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# ###--------- Data cleaning -----------###

# %%
df_raw = df.copy()

# %%
df.duplicated().any()
# Out:
# np.True_

# %%
df.duplicated().sum()
# Out:
# np.int64(5240)

# %%
df[df.duplicated()]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 517    2010-12-01 11:45:00       1.25     17908.0  United Kingdom
# 527    2010-12-01 11:45:00       2.10     17908.0  United Kingdom
# 537    2010-12-01 11:45:00       2.95     17908.0  United Kingdom
# 539    2010-12-01 11:45:00       4.95     17908.0  United Kingdom
# 555    2010-12-01 11:49:00       2.95     17920.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541675 2011-12-09 11:34:00       0.39     14446.0  United Kingdom
# 541689 2011-12-09 11:34:00       2.49     14446.0  United Kingdom
# 541692 2011-12-09 11:34:00       1.95     14446.0  United Kingdom
# 541699 2011-12-09 11:34:00       2.10     14446.0  United Kingdom
# 541701 2011-12-09 11:34:00       2.08     14446.0  United Kingdom
#
# [5240 rows x 8 columns]

# %%
df_duplicates = df[df.duplicated()]

# %%
#df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (533037, 8)

# %%
df_raw.drop_duplicates(inplace=True)

# %%
df_raw.dropna(inplace=True)

# %%
df_raw
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [392760 rows x 8 columns]

# %%
df_raw = df_raw.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# Out:
# C:\Users\Richmond\AppData\Local\Temp\ipykernel_13540\21553454.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_raw = df_raw.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df_raw.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df_raw[df_raw["InvoiceNo"].str.startswith("C", na=False)]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 24162    C538341     22976     CIRCUS PARADE CHILDRENS EGG CUP       -12
# 24168    C538341     22730          ALARM CLOCK BAKELIKE IVORY        -1
# 24176    C538341     22727            ALARM CLOCK BAKELIKE RED        -2
# 24177    C538341     22727            ALARM CLOCK BAKELIKE RED        -1
# 24181    C538341     22726          ALARM CLOCK BAKELIKE GREEN        -1
# 24183    C538341     22725      ALARM CLOCK BAKELIKE CHOCOLATE        -1
# 49858    C540535     21232      STRAWBERRY CERAMIC TRINKET BOX        -1
# 86890    C543611     82483  WOOD 2 DRAWER CABINET WHITE FINISH        -1
# 89276    C543837     22423            REGENCY CAKESTAND 3 TIER        -2
# 140830   C548469     22624                IVORY KITCHEN SCALES        -4
# 156769   C550165     22962               JAM JAR WITH PINK LID        -1
# 215598   C555723     22171    3 HOOK PHOTO SHELF ANTIQUE WHITE        -2
# 273687   C560855     22367     CHILDRENS APRON SPACEBOY DESIGN        -1
# 293157   C562582     21452                 TOADSTOOL MONEY BOX        -1
# 361730   C568370    90199C     5 STRAND GLASS NECKLACE CRYSTAL        -1
# 361733   C568370     90148  LONG SILVER NECKLACE PASTEL FLOWER        -1
# 361735   C568370     90143     SILVER BRACELET W PASTEL FLOWER        -1
# 362299   C568419    51014C              FEATHER PEN,COAL BLACK       -96
# 384042   C570099     22064           PINK DOUGHNUT TRINKET POT        -1
# 390546   C570556     22568               FELTCRAFT CUSHION OWL      -144
# 390548   C570556     20971    PINK BLUE FELT CRAFT TRINKET BOX     -1296
# 390549   C570556     20969   RED FLORAL FELTCRAFT SHOULDER BAG      -144
# 407565   C571893     22720    SET OF 3 CAKE TINS PANTRY DESIGN        -3
# 411644   C572226     85066         CREAM SWEETHEART MINI CHEST        -1
# 436251   C574095     22326  ROUND SNACK BOXES SET OF4 WOODLAND        -1
# 440149   C574510     22360     GLASS JAR ENGLISH CONFECTIONERY        -1
# 461408   C575940     23309  SET OF 60 I LOVE LONDON CAKE CASES       -24
# 529981   C580764     22667                RECIPE BOX RETROSPOT       -12
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 24162  2010-12-10 14:03:00       1.25     15514.0  United Kingdom
# 24168  2010-12-10 14:03:00       3.75     15514.0  United Kingdom
# 24176  2010-12-10 14:03:00       3.75     15514.0  United Kingdom
# 24177  2010-12-10 14:03:00       3.75     15514.0  United Kingdom
# 24181  2010-12-10 14:03:00       3.75     15514.0  United Kingdom
# 24183  2010-12-10 14:03:00       3.75     15514.0  United Kingdom
# 49858  2011-01-09 14:17:00       1.25     15005.0  United Kingdom
# 86890  2011-02-10 14:38:00       4.95     17850.0  United Kingdom
# 89276  2011-02-14 10:56:00      12.75     14431.0  United Kingdom
# 140830 2011-03-31 12:32:00       7.65     14543.0  United Kingdom
# 156769 2011-04-14 16:34:00       0.85     15358.0  United Kingdom
# 215598 2011-06-06 16:21:00       8.50     15737.0  United Kingdom
# 273687 2011-07-21 13:00:00       1.95     14410.0  United Kingdom
# 293157 2011-08-07 13:53:00       2.95     15640.0  United Kingdom
# 361730 2011-09-26 16:43:00       6.35     15154.0  United Kingdom
# 361733 2011-09-26 16:43:00      12.75     15154.0  United Kingdom
# 361735 2011-09-26 16:43:00       7.50     15154.0  United Kingdom
# 362299 2011-09-27 11:16:00       0.39     13694.0  United Kingdom
# 384042 2011-10-07 12:11:00       1.45     13798.0  United Kingdom
# 390546 2011-10-11 11:10:00       3.39     16029.0  United Kingdom
# 390548 2011-10-11 11:10:00       1.06     16029.0  United Kingdom
# 390549 2011-10-11 11:10:00       3.39     16029.0  United Kingdom
# 407565 2011-10-19 14:13:00       4.95     13314.0  United Kingdom
# 411644 2011-10-21 13:58:00      12.75     15321.0  United Kingdom
# 436251 2011-11-03 09:54:00       2.95     12674.0          France
# 440149 2011-11-04 13:25:00       2.95     15110.0  United Kingdom
# 461408 2011-11-13 11:38:00       0.55     17838.0  United Kingdom
# 529981 2011-12-06 10:38:00       2.95     14562.0  United Kingdom

# %%
df_raw = df_raw[~df_raw["InvoiceNo"].str.startswith("C", na=False)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [392732 rows x 8 columns]

# %%
df_raw
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [392760 rows x 8 columns]
